# %% [markdown]
# # Clustering Using Pycaret

# %% [markdown]
# ### Importing Libraries and Dataset:

# %%
pip install pycaret

# %%
import pandas as pd
from pycaret.clustering import *
import plotly.io as pio
from pycaret.datasets import get_data
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("dataset1.csv")

# %%
dataset_new=dataset.drop(columns = ['User ID'])

# %%
dataset_new
# Out:
#      Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0          0.93        1.80        2.29        0.62        0.80        2.42
# 1          1.02        2.20        2.66        0.64        1.42        3.18
# 2          1.22        0.80        0.54        0.53        0.24        1.54
# 3          0.45        1.80        0.29        0.57        0.46        1.52
# 4          0.51        1.20        1.18        0.57        1.54        2.02
# ..          ...         ...         ...         ...         ...         ...
# 975        0.74        1.12        0.30        0.53        0.88        1.38
# 976        1.25        0.92        1.12        0.38        0.78        1.68
# 977        0.61        1.32        0.67        0.43        1.30        1.78
# 978        0.93        0.20        0.13        0.43        0.30        0.40
# 979        0.93        0.56        1.13        0.51        1.34        2.36
#
#      Category 7  Category 8  Category 9  Category 10
# ...

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(5,5))
dend = shc.dendrogram(shc.linkage(dataset_new,method='ward'))

# %% [markdown]
# ## K Means Clustering

# %% [markdown]
# #### K Means Clustering without PreProcessing

# %%
kmeans_without_preprocessing = setup(data = dataset_new)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
plot_model(_3clustermodel, plot='silhouette')
plot_model(_3clustermodel, plot='distribution')
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
plot_model(_4clustermodel, plot='silhouette')
plot_model(_4clustermodel, plot='distribution')
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
plot_model(_5clustermodel, plot='silhouette')
plot_model(_5clustermodel, plot='distribution')

# %% [markdown]
# To Find the optimal number of Clusters

# %%
plot_model(_5clustermodel, plot='elbow')

# %% [markdown]
# #### K Means Using Normalisation

# %%
kmeans_normalisation = setup(data = dataset_new, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel_n = create_model('kmeans', num_clusters = 3)
_3clusterprediction_n = assign_model(_3clustermodel_n)

print("For Cluster = 4")
_4clustermodel_n = create_model('kmeans', num_clusters = 4)
_4clusterprediction_n = assign_model(_4clustermodel_n)

print("For Cluster = 5")
_5clustermodel_n = create_model('kmeans', num_clusters = 5)
_5clusterprediction_n = assign_model(_5clustermodel_n)

# %%
print("For C = 3")
plot_model(_3clustermodel_n, plot='cluster')
plot_model(_3clustermodel_n, plot='silhouette')
plot_model(_3clustermodel_n, plot='distribution')
print("For C = 4")
plot_model(_4clustermodel_n, plot='cluster')
plot_model(_4clustermodel_n, plot='silhouette')
plot_model(_4clustermodel_n, plot='distribution')
print("For C = 5")
plot_model(_5clustermodel_n, plot='cluster')
plot_model(_5clustermodel_n, plot='silhouette')
plot_model(_5clustermodel_n, plot='distribution')

# %%
plot_model(_5clustermodel_n, plot='elbow')

# %% [markdown]
# #### K Means using PCA

# %%
kmeans_pca = setup(data = dataset_new, pca = True, pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel_pca = create_model('kmeans', num_clusters = 3)
_3clusterprediction_pca = assign_model(_3clustermodel_pca)

print("For Cluster = 4")
_4clustermodel_pca = create_model('kmeans', num_clusters = 4)
_4clusterprediction_pca = assign_model(_4clustermodel_pca)

print("For Cluster = 5")
_5clustermodel_pca = create_model('kmeans', num_clusters = 5)
_5clusterprediction_pca = assign_model(_5clustermodel_pca)

# %%
print("For C = 3")
plot_model(_3clustermodel_pca, plot='cluster')
plot_model(_3clustermodel_pca, plot='silhouette')
plot_model(_3clustermodel_pca, plot='distribution')
print("For C = 4")
plot_model(_4clustermodel_pca, plot='cluster')
plot_model(_4clustermodel_pca, plot='silhouette')
plot_model(_4clustermodel_pca, plot='distribution')
print("For C = 5")
plot_model(_5clustermodel_pca, plot='cluster')
plot_model(_5clustermodel_pca, plot='silhouette')
plot_model(_5clustermodel_pca, plot='distribution')

# %%
plot_model(_5clustermodel_pca, plot='elbow')

# %% [markdown]
# #### K Means Using Transformation+Normalization

# %%
kmeans_t_n = setup(data = dataset_new, transformation = True, normalize = True,normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel_t_n = create_model('kmeans', num_clusters = 3)
_3clusterprediction_t_n = assign_model( _3clustermodel_t_n)

print("For Cluster = 4")
_4clustermodel_t_n = create_model('kmeans', num_clusters = 4)
_4clusterprediction_t_n = assign_model(_4clustermodel_t_n)

print("For Cluster = 5")
_5clustermodel_t_n = create_model('kmeans', num_clusters = 5)
_5clusterprediction_t_n = assign_model(_5clustermodel_t_n)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a5039">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5039_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a5039_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a5039_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a5039_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a5039_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a5039_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5039_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5039_row0_col0" class="data row0 col0" >0.1408</td>
#       <td id="T_a5039_row0_col1" class="data row0 col1" >197.8177</td>
# ...

# %%
print("For C = 3")
plot_model(_3clustermodel_t_n, plot='cluster')
plot_model(_3clustermodel_t_n, plot='silhouette')
plot_model(_3clustermodel_t_n, plot='distribution')
print("For C = 4")
plot_model(_4clustermodel_t_n, plot='cluster')
plot_model(_4clustermodel_t_n, plot='silhouette')
plot_model(_4clustermodel_t_n, plot='distribution')
print("For C = 5")
plot_model(_5clustermodel_t_n, plot='cluster')
plot_model(_5clustermodel_t_n, plot='silhouette')
plot_model(_5clustermodel_t_n, plot='distribution')
# Out:
# For C = 3
# For C = 4
# For C = 5

# %%
plot_model(_5clustermodel_t_n, plot='elbow')

# %% [markdown]
# #### K Means Using Transformation + Normalization + PCA

# %%
kmeans_t_n_p = setup(data = dataset_new, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel_t_n_p = create_model('kmeans', num_clusters = 3)
_3clusterprediction_t_n_p = assign_model( _3clustermodel_t_n_p)

print("For Cluster = 4")
_4clustermodel_t_n_p = create_model('kmeans', num_clusters = 4)
_4clusterprediction_t_n_p = assign_model(_4clustermodel_t_n_p)

print("For Cluster = 5")
_5clustermodel_t_n_p = create_model('kmeans', num_clusters = 5)
_5clusterprediction_t_p = assign_model(_5clustermodel_t_n_p)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_61a05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61a05_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_61a05_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_61a05_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_61a05_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_61a05_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_61a05_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61a05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61a05_row0_col0" class="data row0 col0" >0.1398</td>
#       <td id="T_61a05_row0_col1" class="data row0 col1" >197.8308</td>
# ...

# %%
print("For C = 3")
plot_model(_3clustermodel_t_n_p, plot='cluster')
plot_model(_3clustermodel_t_n_p, plot='silhouette')
plot_model(_3clustermodel_t_n_p, plot='distribution')
print("For C = 4")
plot_model(_4clustermodel_t_n_p, plot='cluster')
plot_model(_4clustermodel_t_n_p, plot='silhouette')
plot_model(_4clustermodel_t_n_p, plot='distribution')
print("For C = 5")
plot_model(_5clustermodel_t_n_p, plot='cluster')
plot_model(_5clustermodel_t_n_p, plot='silhouette')
plot_model(_5clustermodel_t_n_p, plot='distribution')
# Out:
# For C = 3
# For C = 4
# For C = 5

# %%
plot_model(_5clustermodel_t_n_p, plot='elbow')

# %% [markdown]
# ## Hierarchical Clustering

# %%
hier_without_preprocessing = setup(dataset_new)
# Out:
# <style type="text/css">
# #T_1254f_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1254f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1254f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1254f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1254f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1254f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1254f_row0_col1" class="data row0 col1" >7309</td>
#     </tr>
#     <tr>
#       <th id="T_1254f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1254f_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_1254f_row1_col1" class="data row1 col1" >(980, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_1254f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
print("For Cluster = 3")
_3hiermodel = create_model('hclust', num_clusters = 3)
_3hierprediction = assign_model(_3hiermodel)

print("For Cluster = 4")
_4hiermodel = create_model('hclust', num_clusters = 4)
_4hierprediction = assign_model(_4hiermodel)

print("For Cluster = 5")
_5hiermodel = create_model('hclust', num_clusters = 5)
_5hierprediction = assign_model(_5hiermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_d4290">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4290_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d4290_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d4290_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d4290_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d4290_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d4290_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4290_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4290_row0_col0" class="data row0 col0" >0.2187</td>
#       <td id="T_d4290_row0_col1" class="data row0 col1" >263.4422</td>
# ...

# %%
print("For C = 3")
plot_model(_3hiermodel, plot='cluster')
plot_model(_3hiermodel, plot='distribution')

print("For C = 4")
plot_model(_4hiermodel, plot='cluster')
plot_model(_4hiermodel, plot='distribution')
print("For C = 5")
plot_model(_5hiermodel, plot='cluster')
plot_model(_5hiermodel, plot='distribution')
# Out:
# For C = 3
# For C = 4
# For C = 5
